# %%
import re
import json
import pickle
from pathlib import Path
from collections import OrderedDict, Counter

# %%
INPUT_FILE = "../../data/flairs/flairs_processed.jsonl"
OUTPUT_FILE = "../../data/flairs/flars_ready.json"
TEMP_OUTPUT_FILE = "../../data/temp/flars_ready.json"
RAW_FLAIR_FILE = "../../data/flairs/flairs_raw.pkl"

REGION_REGEX_PATTERN = r"((?<=\()(\w+)(?=\)))|((?<=(,\s))(\w+))"
ENTRY_TEMPLATE_KEYS = ("region_original", "region_extended", "region_country")

# %% [markdown]
# CRIM Crimea, MORO Northern Ireland

# %%
def read_temp_or_initialize_dict(temp_file):
    """Attempts to read already annotated temporary data file if exists,
       else return empty dict to be populated
    """
    if temp_file.exists() and temp_file.is_file():
        try:
            flairs = json.load(temp_file.open("r"))
            print("Existing annotations loaded from {}:".format(TEMP_OUTPUT_FILE))
            print(list(flairs.keys()))
        except json.JSONDecodeError as e:
            raise    
    else:
        flairs = OrderedDict()
    
    return flairs
        

def resolve_region_extended(region_original, input_country):
    country_match = re.search(REGION_REGEX_PATTERN, region_original)
    
    if input_country.strip():
        # User prompt not empty:
        if country_match:
            # Country is already mentioned in `region_original` but so in the user prompt, 
            # meaning it's needed to be corrected with the prompt input
            # e.g. "Moravia (Czechia)" -> "Moravia (Czech Republic)"
            if "," in region_original:
                # Region and country are seperated by a comma
                region, _ = re.split(r",\s*", region_original)
            else:
                # Region and country are seperated by a whitespace, country is in parantheses
                region, _ = re.split(r"\s*\(", region_original)
    
        else:
            # Country is not mentioned in `region_original`, 
            # meaning only region is mentioned in `region_original`
            region = region_original
        
        region_extended = "{} ({})".format(region, input_country)
                
    else:
        # User prompt is empty
        if country_match:
            # All relevant information is already in the `region_original`
            if "," in region_original:
                # Region and country are seperated by a comma 
                # and just needs to be reformatted in the correct format
                # e.g. "Veneto, Italy" -> "Veneto (Italy)"
                region, country = re.split(r",\s*", region_original)
                region_extended = "{} ({})".format(region, country)
            else:
                # Region and country are seperated by a whitespace, country is in parantheses,
                # therefore in the correct format already
                region_extended = region_original
        else:
            # `region_original` only contains country information
            # and therefore in acceptable format already
            region_extended = region_original
            
    return region_extended

# %%
assert resolve_region_extended("Poltava (Ukraine)", "") == "Poltava (Ukraine)"
assert resolve_region_extended("Moravia (Czechia)", "Czech Republic") == "Moravia (Czech Republic)"
assert resolve_region_extended("Veneto, Italy","") == "Veneto (Italy)"
assert resolve_region_extended("Lithuania","") == "Lithuania"
assert resolve_region_extended("Åland","Finland") == "Åland (Finland)"

# %%
# Reorganizing input .jsonl file to JSON format with original flair ids as dictionary entry keys
flairs = read_temp_or_initialize_dict(temp_file=Path(TEMP_OUTPUT_FILE))

with open(INPUT_FILE, "r", encoding="utf8") as fp:
    for line in fp:
        dict_ = json.loads(line)
        flair_id = dict_["key"]
        region_original = dict_["value"]
        
        # Skip unknown entries and save them to a seperate list
        if not region_original or flair_id in flairs.keys():
            continue
        
        try:
            # Prompting user for country based on the original flair text
            input_country = input("Country of {}: {} ".format(flair_id, region_original))
        except KeyboardInterrupt:
            # If kernel is interrupted, save the existing annotated data to a temp file
            temp_file = Path(TEMP_OUTPUT_FILE)
            temp_file.parent.mkdir(exist_ok=True)
            with temp_file.open("w", encoding="utf8") as fp:
                json.dump(flairs, fp, ensure_ascii=False, indent=4)
            print("Annotated data saved to ", TEMP_OUTPUT_FILE)
            raise
        else:
            # Populating output dictionary values with another empty dict with flair ids as key
            flairs[flair_id] = dict.fromkeys(ENTRY_TEMPLATE_KEYS, None)
            
            region_extended = resolve_region_extended(region_original, input_country)
            country_match = re.search(REGION_REGEX_PATTERN, region_extended)
            region_country = country_match.group(0) if country_match else region_extended

            # Populating the resulting empty dict with processed  values
            entry_values = (region_original, region_extended, region_country)
            for key, value in zip(ENTRY_TEMPLATE_KEYS, entry_values):
                flairs[flair_id][key] = value

            print(flairs[flair_id]) # Printing the output to visualize the resulting entry
# Out:
# Existing annotations loaded from ../../data/temp/flars_ready.json:
# dict_keys(['AALA', 'ABRZ', 'ADYG', 'ALBA', 'ALGE', 'AMST', 'APUL', 'ARGE', 'ARME', 'ASTR', 'AT-1', 'AT-2', 'AT-3', 'AT-4', 'AT-5', 'AT-6', 'AT-7', 'AT-8', 'AT-9', 'AUST', 'AZER', 'BANG', 'BELA', 'BELG', 'BOLI', 'BORN', 'BOSN', 'BOUV', 'BRAZ', 'BRUX', 'BUCU', 'BULG', 'CALA', 'CANA', 'CH-AG', 'CH-BE', 'CH-BL', 'CH-BS', 'CH-GE', 'CH-GR', 'CH-LU', 'CH-NE', 'CH-SG', 'CH-SH', 'CH-TI', 'CH-ZG', 'CH-ZH', 'CHIL', 'CHIN', 'CMPN', 'CONN', 'CRIM', 'CROA', 'CUBA', 'CYPR', 'CZ-10', 'CZEC', 'DALM', 'DE-BB', 'DE-BE', 'DE-BW', 'DE-BY', 'DE-HB', 'DE-HE', 'DE-HH', 'DE-MV', 'DE-NI', 'DE-NW', 'DE-RP', 'DE-SH', 'DE-SL', 'DE-SN', 'DE-ST', 'DE-TH', 'DENK', 'DMRP', 'EFRE', 'EGYP', 'EMRM', 'ENGL', 'ES-AN'])
# Country of ES-AR: Aragon (Spain)
# {'region_original': 'Aragon (Spain)', 'region_extended': 'Aragon (Spain)', 'region_country': 'Spain'}
# Country of ES-AS: Asturias (Spain)
# {'region_original': 'Asturias (Spain)', 'region_extended': 'Asturias (Spain)', 'region_country': 'Spain'}
# Country of ES-CB: Cantabria (Spain)
# {'region_original': 'Cantabria (Spain)', 'region_extended': 'Cantabria (Spain)', 'region_country': 'Spain'}
# Country of ES-CE: Ceuta (Spain)
# {'region_original': 'Ceuta (Spain)', 'region_extended': 'Ceuta (Spain)', 'region_country': 'Spain'}
# Country of ES-CL: Castile and León (Spain)
# {'region_original': 'Castile and León (Spain)', 'region_extended': 'Castile and León (Spain)', 'region_country': 'Spain'}
# Country of ES-CM: Castilla-La Mancha (Spain)
# {'region_original': 'Castilla-La Mancha (Spain)', 'region_extended': 'Castilla-La Mancha (Spain)', 'region_country': 'Spain'}
# Country of ES-CN: Canary Islands (Spain)
# {'region_original': 'Canary Islands (Spain)', 'region_extended': 'Canary Islands (Spain)', 'region_country': 'Spain'}
# Country of ES-CT: Catalonia (Spain)
# {'region_original': 'Catalonia (Spain)', 'region_extended': 'Catalonia (Spain)', 'region_country': 'Spain'}
# Country of ES-EX: Extremadura (Spain)
# {'region_original': 'Extremadura (Spain)', 'region_extended': 'Extremadura (Spain)', 'region_country': 'Spain'}
# Country of ES-GA: Galicia (Spain)
# {'region_original': 'Galicia (Spain)', 'region_extended': 'Galicia (Spain)', 'region_country': 'Spain'}
# Country of ES-IB: Balearic Islands (Spain)
# {'region_original': 'Balearic Islands (Spain)', 'region_extended': 'Balearic Islands (Spain)', 'region_country': 'Spain'}
# Country of ES-MC: Region of Murcia (Spain)
# {'region_original': 'Region of Murcia (Spain)', 'region_extended': 'Region of Murcia (Spain)', 'region_country': 'Spain'}
# Country of ES-MD: Community of Madrid (Spain)
# {'region_original': 'Community of Madrid (Spain)', 'region_extended': 'Community of Madrid (Spain)', 'region_country': 'Spain'}
# Country of ES-ML: Melilla Spain
# {'region_original': 'Melilla', 'region_extended': 'Melilla (Spain)', 'region_country': 'Spain'}
# Country of ES-NC: Navarre (Spain)
# {'region_original': 'Navarre (Spain)', 'region_extended': 'Navarre (Spain)', 'region_country': 'Spain'}
# Country of ES-PV: Basque Country (Spain)
# {'region_original': 'Basque Country (Spain)', 'region_extended': 'Basque Country (Spain)', 'region_country': 'Spain'}
# Country of ES-VC: Valencian Community (Spain)
# {'region_original': 'Valencian Community (Spain)', 'region_extended': 'Valencian Community (Spain)', 'region_country': 'Spain'}
# Country of ESPA: Spain
# {'region_original': 'Spain', 'region_extended': 'Spain', 'region_country': 'Spain'}
# Country of ESTO: Estonia
# {'region_original': 'Estonia', 'region_extended': 'Estonia', 'region_country': 'Estonia'}
# Country of FALK: Falkland Islands United Kingdom
# {'region_original': 'Falkland Islands', 'region_extended': 'Falkland Islands (United Kingdom)', 'region_country': 'Falkland Islands (United Kingdom)'}
# Country of FARO: Faroe Islands Denmark
# {'region_original': 'Faroe Islands', 'region_extended': 'Faroe Islands (Denmark)', 'region_country': 'Denmark'}
# Country of FINL: Finland
# {'region_original': 'Finland', 'region_extended': 'Finland', 'region_country': 'Finland'}
# Country of FLAN: Flanders (Belgium)
# {'region_original': 'Flanders (Belgium)', 'region_extended': 'Flanders (Belgium)', 'region_country': 'Belgium'}
# Country of FR-ALSA: Alsace (France)
# {'region_original': 'Alsace (France)', 'region_extended': 'Alsace (France)', 'region_country': 'France'}
# Country of FR-AQUI: Aquitaine (France)
# {'region_original': 'Aquitaine (France)', 'region_extended': 'Aquitaine (France)', 'region_country': 'France'}
# Country of FR-AUVE: Auvergne (France)
# {'region_original': 'Auvergne (France)', 'region_extended': 'Auvergne (France)', 'region_country': 'France'}
# Country of FR-BRIT: Brittany (France)
# {'region_original': 'Brittany (France)', 'region_extended': 'Brittany (France)', 'region_country': 'France'}
# Country of FR-BURG: Burgundy (France)
# {'region_original': 'Burgundy (France)', 'region_extended': 'Burgundy (France)', 'region_country': 'France'}
# Country of FR-CHAR: Champagne-Ardenne (France)
# {'region_original': 'Champagne-Ardenne (France)', 'region_extended': 'Champagne-Ardenne (France)', 'region_country': 'France'}
# Country of FR-CORS: Corsica (Corsica) France
# {'region_original': 'Corsica (Corsica)', 'region_extended': 'Corsica (France)', 'region_country': 'France'}
# Country of FR-CVDL: Centre-Val de Loire (France)
# {'region_original': 'Centre-Val de Loire (France)', 'region_extended': 'Centre-Val de Loire (France)', 'region_country': 'France'}
# Country of FR-FCOM: Franche-Comté (France)
# {'region_original': 'Franche-Comté (France)', 'region_extended': 'Franche-Comté (France)', 'region_country': 'France'}
# Country of FR-GUIA: French Guiana France
# {'region_original': 'French Guiana', 'region_extended': 'French Guiana (France)', 'region_country': 'France'}
# Country of FR-IDFR: Île-de-France France
# {'region_original': 'Île-de-France', 'region_extended': 'Île-de-France (France)', 'region_country': 'France'}
# Country of FR-LARO: Languedoc-Roussillon (France)
# {'region_original': 'Languedoc-Roussillon (France)', 'region_extended': 'Languedoc-Roussillon (France)', 'region_country': 'France'}
# Country of FR-LNOR: Lower Normandy (France)
# {'region_original': 'Lower Normandy (France)', 'region_extended': 'Lower Normandy (France)', 'region_country': 'France'}
# Country of FR-LORR: Lorraine (France)
# {'region_original': 'Lorraine (France)', 'region_extended': 'Lorraine (France)', 'region_country': 'France'}
# Country of FR-MART: Martinique (France)
# {'region_original': 'Martinique (France)', 'region_extended': 'Martinique (France)', 'region_country': 'France'}
# Country of FR-MPYR: Midi-Pyrénées (France)
# {'region_original': 'Midi-Pyrénées (France)', 'region_extended': 'Midi-Pyrénées (France)', 'region_country': 'France'}
# Country of FR-NPDC: Nord-Pas-de-Calais (France)
# {'region_original': 'Nord-Pas-de-Calais (France)', 'region_extended': 'Nord-Pas-de-Calais (France)', 'region_country': 'France'}
# Country of FR-PACA: Provence-Alpes-Côte d'Azur (France)
# {'region_original': "Provence-Alpes-Côte d'Azur (France)", 'region_extended': "Provence-Alpes-Côte d'Azur (France)", 'region_country': 'France'}
# Country of FR-PDLR: Pays de la Loire (France)
# {'region_original': 'Pays de la Loire (France)', 'region_extended': 'Pays de la Loire (France)', 'region_country': 'France'}
# Country of FR-PICA: Picardie (France)
# {'region_original': 'Picardie (France)', 'region_extended': 'Picardie (France)', 'region_country': 'France'}
# Country of FR-POIT: Poitou-Charentes (France)
# {'region_original': 'Poitou-Charentes (France)', 'region_extended': 'Poitou-Charentes (France)', 'region_country': 'France'}
# Country of FR-REUN: Réunion (France)
# {'region_original': 'Réunion (France)', 'region_extended': 'Réunion (France)', 'region_country': 'France'}
# Country of FR-RHAL: Rhône-Alpes (France)
# {'region_original': 'Rhône-Alpes (France)', 'region_extended': 'Rhône-Alpes (France)', 'region_country': 'France'}
# Country of FR-UNOR: Upper Normandy (France)
# {'region_original': 'Upper Normandy (France)', 'region_extended': 'Upper Normandy (France)', 'region_country': 'France'}
# Country of FRAN: France
# {'region_original': 'France', 'region_extended': 'France', 'region_country': 'France'}
# Country of FRNK: Franconia (Germany)
# {'region_original': 'Franconia (Germany)', 'region_extended': 'Franconia (Germany)', 'region_country': 'Germany'}
# Country of FVEG: Friuli-Venezia Giulia Italy
# {'region_original': 'Friuli-Venezia Giulia', 'region_extended': 'Friuli-Venezia Giulia (Italy)', 'region_country': 'Italy'}
# Country of GEOR: Georgia
# {'region_original': 'Georgia', 'region_extended': 'Georgia', 'region_country': 'Georgia'}
# Country of GERM: Germany
# {'region_original': 'Germany', 'region_extended': 'Germany', 'region_country': 'Germany'}
# Country of GIBR: Gibraltar United Kingdom
# {'region_original': 'Gibraltar', 'region_extended': 'Gibraltar (United Kingdom)', 'region_country': 'Gibraltar (United Kingdom)'}
# Country of GNLD: Greenland Denmark
# {'region_original': 'Greenland', 'region_extended': 'Greenland (Denmark)', 'region_country': 'Denmark'}
# Country of GREE: Greece
# {'region_original': 'Greece', 'region_extended': 'Greece', 'region_country': 'Greece'}
# Country of GUER: Guernsey United Kingdom
# {'region_original': 'Guernsey', 'region_extended': 'Guernsey (United Kingdom)', 'region_country': 'Guernsey (United Kingdom)'}
# Country of HUNG: Hungary
# {'region_original': 'Hungary', 'region_extended': 'Hungary', 'region_country': 'Hungary'}
# Country of ICEL: Iceland
# {'region_original': 'Iceland', 'region_extended': 'Iceland', 'region_country': 'Iceland'}
# Country of INDI: India
# {'region_original': 'India', 'region_extended': 'India', 'region_country': 'India'}
# Country of INDO: Indonesia
# {'region_original': 'Indonesia', 'region_extended': 'Indonesia', 'region_country': 'Indonesia'}
# Country of IQ: Iraq
# {'region_original': 'Iraq', 'region_extended': 'Iraq', 'region_country': 'Iraq'}
# Country of IRAN: Iran
# {'region_original': 'Iran', 'region_extended': 'Iran', 'region_country': 'Iran'}
# Country of IREL: Ireland
# {'region_original': 'Ireland', 'region_extended': 'Ireland', 'region_country': 'Ireland'}
# Country of ISOM: Isle of Man United Kingdom
# {'region_original': 'Isle of Man', 'region_extended': 'Isle of Man (United Kingdom)', 'region_country': 'Isle of Man (United Kingdom)'}
# Country of ISRA: Israel
# {'region_original': 'Israel', 'region_extended': 'Israel', 'region_country': 'Israel'}
# Country of ITAL: Italy
# {'region_original': 'Italy', 'region_extended': 'Italy', 'region_country': 'Italy'}
# Country of JAPA: Japan
# {'region_original': 'Japan', 'region_extended': 'Japan', 'region_country': 'Japan'}
# Country of JERS: Jersey United Kingdom
# {'region_original': 'Jersey', 'region_extended': 'Jersey (United Kingdom)', 'region_country': 'Jersey (United Kingdom)'}
# Country of JORD: Jordan
# {'region_original': 'Jordan', 'region_extended': 'Jordan', 'region_country': 'Jordan'}
# Country of KAZA: Kazakhstan
# {'region_original': 'Kazakhstan', 'region_extended': 'Kazakhstan', 'region_country': 'Kazakhstan'}
# Country of KOSV: Kosovo
# {'region_original': 'Kosovo', 'region_extended': 'Kosovo', 'region_country': 'Kosovo'}
# Country of KUWA: Kuwait
# {'region_original': 'Kuwait', 'region_extended': 'Kuwait', 'region_country': 'Kuwait'}
# Country of KWTG: Kingdom of Württemberg (Germany)
# {'region_original': 'Kingdom of Württemberg (Germany)', 'region_extended': 'Kingdom of Württemberg (Germany)', 'region_country': 'Germany'}
# Country of LATV: Latvia
# {'region_original': 'Latvia', 'region_extended': 'Latvia', 'region_country': 'Latvia'}
# Country of LAZI: Lazio Italy
# {'region_original': 'Lazio', 'region_extended': 'Lazio (Italy)', 'region_country': 'Italy'}
# Country of LEBA: Lebanon
# {'region_original': 'Lebanon', 'region_extended': 'Lebanon', 'region_country': 'Lebanon'}
# Country of LEIN: Leinster Ireland
# {'region_original': 'Leinster', 'region_extended': 'Leinster (Ireland)', 'region_country': 'Ireland'}
# Country of LIEC: Liechtenstein
# {'region_original': 'Liechtenstein', 'region_extended': 'Liechtenstein', 'region_country': 'Liechtenstein'}
# Country of LIGU: Liguria Italy
# {'region_original': 'Liguria', 'region_extended': 'Liguria (Italy)', 'region_country': 'Italy'}
# Country of LIMB: Limburg, Netherlands
# {'region_original': 'Limburg, Netherlands', 'region_extended': 'Limburg (Netherlands)', 'region_country': 'Netherlands'}
# Country of LITH: Lithuania
# {'region_original': 'Lithuania', 'region_extended': 'Lithuania', 'region_country': 'Lithuania'}
# Country of LOMB: Lombardy Italy
# {'region_original': 'Lombardy', 'region_extended': 'Lombardy (Italy)', 'region_country': 'Italy'}
# Country of LUXE: Luxembourg
# {'region_original': 'Luxembourg', 'region_extended': 'Luxembourg', 'region_country': 'Luxembourg'}
# Country of LV-DAUG: Daugavpils (Latvia)
# {'region_original': 'Daugavpils (Latvia)', 'region_extended': 'Daugavpils (Latvia)', 'region_country': 'Latvia'}
# Country of LV-LIEP: Tuvu Liepājai (Latvia)
# {'region_original': 'Tuvu Liepājai (Latvia)', 'region_extended': 'Tuvu Liepājai (Latvia)', 'region_country': 'Latvia'}
# Country of LV-RIGA: Rīga (Latvia)
# {'region_original': 'Rīga (Latvia)', 'region_extended': 'Rīga (Latvia)', 'region_country': 'Latvia'}
# Country of LV-VALM: Valmiera (Latvia)
# {'region_original': 'Valmiera (Latvia)', 'region_extended': 'Valmiera (Latvia)', 'region_country': 'Latvia'}
# Country of LV-VENT: Ventspils (Latvia)
# {'region_original': 'Ventspils (Latvia)', 'region_extended': 'Ventspils (Latvia)', 'region_country': 'Latvia'}
# Country of MACE: North Macedonia
# {'region_original': 'North Macedonia', 'region_extended': 'North Macedonia', 'region_country': 'North Macedonia'}
# Country of MAKE: Macedonia, Greece
# {'region_original': 'Macedonia, Greece', 'region_extended': 'Macedonia (Greece)', 'region_country': 'Greece'}
# Country of MALT: Malta
# {'region_original': 'Malta', 'region_extended': 'Malta', 'region_country': 'Malta'}
# Country of MALY: Malaysia
# {'region_original': 'Malaysia', 'region_extended': 'Malaysia', 'region_country': 'Malaysia'}
# Country of MEXI: Mexico
# {'region_original': 'Mexico', 'region_extended': 'Mexico', 'region_country': 'Mexico'}
# Country of MNST: Munster (Ireland)
# {'region_original': 'Munster (Ireland)', 'region_extended': 'Munster (Ireland)', 'region_country': 'Ireland'}
# Country of MOLD: Moldova
# {'region_original': 'Moldova', 'region_extended': 'Moldova', 'region_country': 'Moldova'}
# Country of MONA: Monaco
# {'region_original': 'Monaco', 'region_extended': 'Monaco', 'region_country': 'Monaco'}
# Country of MONT: Montenegro
# {'region_original': 'Montenegro', 'region_extended': 'Montenegro', 'region_country': 'Montenegro'}
# Country of MORO: Northern Ireland United Kingdom
# {'region_original': 'Northern Ireland', 'region_extended': 'Northern Ireland (United Kingdom)', 'region_country': 'Northern Ireland (United Kingdom)'}
# Country of MRCH: Marche Italy
# {'region_original': 'Marche', 'region_extended': 'Marche (Italy)', 'region_country': 'Italy'}
# Country of MRVA: Moravia (Czechia) Czech Republic
# {'region_original': 'Moravia (Czechia)', 'region_extended': 'Moravia (Czech Republic)', 'region_country': 'Moravia (Czech Republic)'}
# Country of NETH: The Netherlands
# {'region_original': 'The Netherlands', 'region_extended': 'The Netherlands', 'region_country': 'The Netherlands'}
# Country of NEWZ: New Zealand
# {'region_original': 'New Zealand', 'region_extended': 'New Zealand', 'region_country': 'New Zealand'}
# Country of NL-DR: Drenthe (Netherlands)
# {'region_original': 'Drenthe (Netherlands)', 'region_extended': 'Drenthe (Netherlands)', 'region_country': 'Netherlands'}
# Country of NL-FL: Flevoland (Netherlands)
# {'region_original': 'Flevoland (Netherlands)', 'region_extended': 'Flevoland (Netherlands)', 'region_country': 'Netherlands'}
# Country of NL-FR: Friesland (Netherlands)
# {'region_original': 'Friesland (Netherlands)', 'region_extended': 'Friesland (Netherlands)', 'region_country': 'Netherlands'}
# Country of NL-GE: Gelderland (Netherlands)
# {'region_original': 'Gelderland (Netherlands)', 'region_extended': 'Gelderland (Netherlands)', 'region_country': 'Netherlands'}
# Country of NL-GR: Groningen (Netherlands)
# {'region_original': 'Groningen (Netherlands)', 'region_extended': 'Groningen (Netherlands)', 'region_country': 'Netherlands'}
# Country of NL-LI: Limburg (Netherlands)
# {'region_original': 'Limburg (Netherlands)', 'region_extended': 'Limburg (Netherlands)', 'region_country': 'Netherlands'}
# Country of NL-NB: North Brabant (Netherlands)
# {'region_original': 'North Brabant (Netherlands)', 'region_extended': 'North Brabant (Netherlands)', 'region_country': 'Netherlands'}
# Country of NL-NH: North Holland (Netherlands)
# {'region_original': 'North Holland (Netherlands)', 'region_extended': 'North Holland (Netherlands)', 'region_country': 'Netherlands'}
# Country of NL-OV: Overijssel (Netherlands)
# {'region_original': 'Overijssel (Netherlands)', 'region_extended': 'Overijssel (Netherlands)', 'region_country': 'Netherlands'}
# Country of NL-UT: Utrecht (Netherlands)
# {'region_original': 'Utrecht (Netherlands)', 'region_extended': 'Utrecht (Netherlands)', 'region_country': 'Netherlands'}
# Country of NL-ZE: Zeeland (Netherlands)
# {'region_original': 'Zeeland (Netherlands)', 'region_extended': 'Zeeland (Netherlands)', 'region_country': 'Netherlands'}
# Country of NL-ZH: South Holland (Netherlands)
# {'region_original': 'South Holland (Netherlands)', 'region_extended': 'South Holland (Netherlands)', 'region_country': 'Netherlands'}
# Country of NORM: Normandy (France)
# {'region_original': 'Normandy (France)', 'region_extended': 'Normandy (France)', 'region_country': 'France'}
# Country of NORN: Northern Ireland United Kingdom
# {'region_original': 'Northern Ireland', 'region_extended': 'Northern Ireland (United Kingdom)', 'region_country': 'Northern Ireland (United Kingdom)'}
# Country of NORW: Norway
# {'region_original': 'Norway', 'region_extended': 'Norway', 'region_country': 'Norway'}
# Country of PAKI: Pakistan
# {'region_original': 'Pakistan', 'region_extended': 'Pakistan', 'region_country': 'Pakistan'}
# Country of PALE: Palestine
# {'region_original': 'Palestine', 'region_extended': 'Palestine', 'region_country': 'Palestine'}
# Country of PHIL: Philippines
# {'region_original': 'Philippines', 'region_extended': 'Philippines', 'region_country': 'Philippines'}
# Country of PIED: Piedmont Italy
# {'region_original': 'Piedmont', 'region_extended': 'Piedmont (Italy)', 'region_country': 'Italy'}
# Country of PL-02DS: Lower Silesia (Poland)
# {'region_original': 'Lower Silesia (Poland)', 'region_extended': 'Lower Silesia (Poland)', 'region_country': 'Poland'}
# Country of PL-04KP: Kujawy-Pomerania (Poland)
# {'region_original': 'Kujawy-Pomerania (Poland)', 'region_extended': 'Kujawy-Pomerania (Poland)', 'region_country': 'Poland'}
# Country of PL-06LU: Lublin (Poland)
# {'region_original': 'Lublin (Poland)', 'region_extended': 'Lublin (Poland)', 'region_country': 'Poland'}
# Country of PL-08LB: Lubusz (Poland)
# {'region_original': 'Lubusz (Poland)', 'region_extended': 'Lubusz (Poland)', 'region_country': 'Poland'}
# Country of PL-10LD: Łódź (Poland)
# {'region_original': 'Łódź (Poland)', 'region_extended': 'Łódź (Poland)', 'region_country': 'Poland'}
# Country of PL-12MA: Lesser Poland (Poland)
# {'region_original': 'Lesser Poland (Poland)', 'region_extended': 'Lesser Poland (Poland)', 'region_country': 'Poland'}
# Country of PL-14MZ: Mazovia (Poland)
# {'region_original': 'Mazovia (Poland)', 'region_extended': 'Mazovia (Poland)', 'region_country': 'Poland'}
# Country of PL-16OP: Opole (Poland)
# {'region_original': 'Opole (Poland)', 'region_extended': 'Opole (Poland)', 'region_country': 'Poland'}
# Country of PL-18PK: Subcarpathia (Poland)
# {'region_original': 'Subcarpathia (Poland)', 'region_extended': 'Subcarpathia (Poland)', 'region_country': 'Poland'}
# Country of PL-20PD: Podlaskie (Poland)
# {'region_original': 'Podlaskie (Poland)', 'region_extended': 'Podlaskie (Poland)', 'region_country': 'Poland'}
# Country of PL-22PM: Pomerania (Poland)
# {'region_original': 'Pomerania (Poland)', 'region_extended': 'Pomerania (Poland)', 'region_country': 'Poland'}
# Country of PL-24SL: Silesia (Poland)
# {'region_original': 'Silesia (Poland)', 'region_extended': 'Silesia (Poland)', 'region_country': 'Poland'}
# Country of PL-26SK: Holy Cross (Poland)
# {'region_original': 'Holy Cross (Poland)', 'region_extended': 'Holy Cross (Poland)', 'region_country': 'Poland'}
# Country of PL-28WN: Warmian-Masurian (Poland)
# {'region_original': 'Warmian-Masurian (Poland)', 'region_extended': 'Warmian-Masurian (Poland)', 'region_country': 'Poland'}
# Country of PL-30WP: Greater Poland (Poland)
# {'region_original': 'Greater Poland (Poland)', 'region_extended': 'Greater Poland (Poland)', 'region_country': 'Poland'}
# Country of PL-32ZP: West Pomerania (Poland)
# {'region_original': 'West Pomerania (Poland)', 'region_extended': 'West Pomerania (Poland)', 'region_country': 'Poland'}
# Country of POLA: Poland
# {'region_original': 'Poland', 'region_extended': 'Poland', 'region_country': 'Poland'}
# Country of PORT: Portugal
# {'region_original': 'Portugal', 'region_extended': 'Portugal', 'region_country': 'Portugal'}
# Country of PT-20: Azores (Portugal)
# {'region_original': 'Azores (Portugal)', 'region_extended': 'Azores (Portugal)', 'region_country': 'Portugal'}
# Country of PT-30: Madeira (Portugal)
# {'region_original': 'Madeira (Portugal)', 'region_extended': 'Madeira (Portugal)', 'region_country': 'Portugal'}
# Country of ROMA: Romania
# {'region_original': 'Romania', 'region_extended': 'Romania', 'region_country': 'Romania'}
# Country of RU-KR: Karelia (Russia)
# {'region_original': 'Karelia (Russia)', 'region_extended': 'Karelia (Russia)', 'region_country': 'Russia'}
# Country of RU-MOW: Moscow (Russia)
# {'region_original': 'Moscow (Russia)', 'region_extended': 'Moscow (Russia)', 'region_country': 'Russia'}
# Country of RU-SPE: St. Petersburg (Russia)
# {'region_original': 'St. Petersburg (Russia)', 'region_extended': 'St. Petersburg (Russia)', 'region_country': 'Russia'}
# Country of RUSS: Russia
# {'region_original': 'Russia', 'region_extended': 'Russia', 'region_country': 'Russia'}
# Country of SARD: Sardinia Italy
# {'region_original': 'Sardinia', 'region_extended': 'Sardinia (Italy)', 'region_country': 'Italy'}
# Country of SCIL: Sicily Italy
# {'region_original': 'Sicily', 'region_extended': 'Sicily (Italy)', 'region_country': 'Italy'}
# Country of SCOT: Scotland United Kingdom
# {'region_original': 'Scotland', 'region_extended': 'Scotland (United Kingdom)', 'region_country': 'Scotland (United Kingdom)'}
# Country of SERB: Serbia
# {'region_original': 'Serbia', 'region_extended': 'Serbia', 'region_country': 'Serbia'}
# Country of SI-061: Ljubljana (Slovenia)
# {'region_original': 'Ljubljana (Slovenia)', 'region_extended': 'Ljubljana (Slovenia)', 'region_country': 'Slovenia'}
# Country of SI-070: Maribor (Slovenia)
# {'region_original': 'Maribor (Slovenia)', 'region_extended': 'Maribor (Slovenia)', 'region_country': 'Slovenia'}
# Country of SING: Singapore
# {'region_original': 'Singapore', 'region_extended': 'Singapore', 'region_country': 'Singapore'}
# Country of SK-BL: Bratislava (Slovakia)
# {'region_original': 'Bratislava (Slovakia)', 'region_extended': 'Bratislava (Slovakia)', 'region_country': 'Slovakia'}
# Country of SKAN: Scania Sweden
# {'region_original': 'Scania', 'region_extended': 'Scania (Sweden)', 'region_country': 'Sweden'}
# Country of SKOR: South Korea
# {'region_original': 'South Korea', 'region_extended': 'South Korea', 'region_country': 'South Korea'}
# Country of SLAV: Slavonia Croatia
# {'region_original': 'Slavonia', 'region_extended': 'Slavonia (Croatia)', 'region_country': 'Croatia'}
# Country of SLOV: Slovenia
# {'region_original': 'Slovenia', 'region_extended': 'Slovenia', 'region_country': 'Slovenia'}
# Country of SNMN: San Marino
# {'region_original': 'San Marino', 'region_extended': 'San Marino', 'region_country': 'San Marino'}
# Country of SOAF: South Africa
# {'region_original': 'South Africa', 'region_extended': 'South Africa', 'region_country': 'South Africa'}
# Country of SRIL: Sri Lanka
# {'region_original': 'Sri Lanka', 'region_extended': 'Sri Lanka', 'region_country': 'Sri Lanka'}
# Country of SUDT: South Tyrol (Italy)
# {'region_original': 'South Tyrol (Italy)', 'region_extended': 'South Tyrol (Italy)', 'region_country': 'Italy'}
# Country of SVAK: Slovakia
# {'region_original': 'Slovakia', 'region_extended': 'Slovakia', 'region_country': 'Slovakia'}
# Country of SWED: Sweden
# {'region_original': 'Sweden', 'region_extended': 'Sweden', 'region_country': 'Sweden'}
# Country of SWIT: Switzerland
# {'region_original': 'Switzerland', 'region_extended': 'Switzerland', 'region_country': 'Switzerland'}
# Country of SYRI: Syria
# {'region_original': 'Syria', 'region_extended': 'Syria', 'region_country': 'Syria'}
# Country of TAIW: Taiwan
# {'region_original': 'Taiwan', 'region_extended': 'Taiwan', 'region_country': 'Taiwan'}
# Country of TRAN: Transylvania Romania
# {'region_original': 'Transylvania', 'region_extended': 'Transylvania (Romania)', 'region_country': 'Romania'}
# Country of TRNT: Trentino-South Tyrol Italy
# {'region_original': 'Trentino-South Tyrol', 'region_extended': 'Trentino-South Tyrol (Italy)', 'region_country': 'Italy'}
# Country of TUNI: Tunisia
# {'region_original': 'Tunisia', 'region_extended': 'Tunisia', 'region_country': 'Tunisia'}
# Country of TURK: Turkey
# {'region_original': 'Turkey', 'region_extended': 'Turkey', 'region_country': 'Turkey'}
# Country of TUSC: Tuscany Italy
# {'region_original': 'Tuscany', 'region_extended': 'Tuscany (Italy)', 'region_country': 'Italy'}
# Country of UA-05: Ukraine
# {'region_original': 'Ukraine', 'region_extended': 'Ukraine', 'region_country': 'Ukraine'}
# Country of UA-07: Volyn (Ukraine)
# {'region_original': 'Volyn (Ukraine)', 'region_extended': 'Volyn (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-09: Luhansk (Ukraine)
# {'region_original': 'Luhansk (Ukraine)', 'region_extended': 'Luhansk (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-12: Dnipro (Ukraine)
# {'region_original': 'Dnipro (Ukraine)', 'region_extended': 'Dnipro (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-14: Donetsk (Ukraine)
# {'region_original': 'Donetsk (Ukraine)', 'region_extended': 'Donetsk (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-18: Zhytomyr (Ukraine)
# {'region_original': 'Zhytomyr (Ukraine)', 'region_extended': 'Zhytomyr (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-21: Zakarpattia (Ukraine)
# {'region_original': 'Zakarpattia (Ukraine)', 'region_extended': 'Zakarpattia (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-23: Zaporizhia (Ukraine)
# {'region_original': 'Zaporizhia (Ukraine)', 'region_extended': 'Zaporizhia (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-26: Ivano-Frankivsk (Ukraine)
# {'region_original': 'Ivano-Frankivsk (Ukraine)', 'region_extended': 'Ivano-Frankivsk (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-30: Kyiv (Ukraine)
# {'region_original': 'Kyiv (Ukraine)', 'region_extended': 'Kyiv (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-32: Kyiv region (Ukraine)
# {'region_original': 'Kyiv region (Ukraine)', 'region_extended': 'Kyiv region (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-35: Ukraine
# {'region_original': 'Ukraine', 'region_extended': 'Ukraine', 'region_country': 'Ukraine'}
# Country of UA-40: Sevastopol (Ukraine)
# {'region_original': 'Sevastopol (Ukraine)', 'region_extended': 'Sevastopol (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-43: Crimea (Ukraine)
# {'region_original': 'Crimea (Ukraine)', 'region_extended': 'Crimea (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-46: Lviv (Ukraine)
# {'region_original': 'Lviv (Ukraine)', 'region_extended': 'Lviv (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-48: Mykolaiv (Ukraine)
# {'region_original': 'Mykolaiv (Ukraine)', 'region_extended': 'Mykolaiv (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-51: Odesa (Ukraine)
# {'region_original': 'Odesa (Ukraine)', 'region_extended': 'Odesa (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-53: Poltava (Ukraine)
# {'region_original': 'Poltava (Ukraine)', 'region_extended': 'Poltava (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-56: Rivne (Ukraine)
# {'region_original': 'Rivne (Ukraine)', 'region_extended': 'Rivne (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-63: Kharkiv (Ukraine)
# {'region_original': 'Kharkiv (Ukraine)', 'region_extended': 'Kharkiv (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-65: Kherson (Ukraine)
# {'region_original': 'Kherson (Ukraine)', 'region_extended': 'Kherson (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-74: Chernihiv (Ukraine)
# {'region_original': 'Chernihiv (Ukraine)', 'region_extended': 'Chernihiv (Ukraine)', 'region_country': 'Ukraine'}
# Country of UA-77: Chernivtsi (Ukraine)
# {'region_original': 'Chernivtsi (Ukraine)', 'region_extended': 'Chernivtsi (Ukraine)', 'region_country': 'Ukraine'}
# Country of UKGB: United Kingdom
# {'region_original': 'United Kingdom', 'region_extended': 'United Kingdom', 'region_country': 'United Kingdom'}
# Country of UKRA: Ukraine
# {'region_original': 'Ukraine', 'region_extended': 'Ukraine', 'region_country': 'Ukraine'}
# Country of UMBR: Umbria Italy
# {'region_original': 'Umbria', 'region_extended': 'Umbria (Italy)', 'region_country': 'Italy'}
# Country of UNSA: United States of America
# {'region_original': 'United States of America', 'region_extended': 'United States of America', 'region_country': 'United States of America'}
# Country of URUG: Uruguay
# {'region_original': 'Uruguay', 'region_extended': 'Uruguay', 'region_country': 'Uruguay'}
# Country of VA: Vatican City
# {'region_original': 'Vatican City', 'region_extended': 'Vatican City', 'region_country': 'Vatican City'}
# Country of VENE: Veneto, Italy
# {'region_original': 'Veneto, Italy', 'region_extended': 'Veneto (Italy)', 'region_country': 'Italy'}
# Country of VENZ: Venezuela
# {'region_original': 'Venezuela', 'region_extended': 'Venezuela', 'region_country': 'Venezuela'}
# Country of VIET: Vietnam
# {'region_original': 'Vietnam', 'region_extended': 'Vietnam', 'region_country': 'Vietnam'}
# Country of VOJV: Vojvodina Serbia
# {'region_original': 'Vojvodina', 'region_extended': 'Vojvodina (Serbia)', 'region_country': 'Serbia'}
# Country of WALE: Wales United Kingdom
# {'region_original': 'Wales', 'region_extended': 'Wales (United Kingdom)', 'region_country': 'Wales (United Kingdom)'}
# Country of WALL: Wallachia (Romania)
# {'region_original': 'Wallachia (Romania)', 'region_extended': 'Wallachia (Romania)', 'region_country': 'Romania'}
# Country of WALN: Wallonia (Belgium)
# {'region_original': 'Wallonia (Belgium)', 'region_extended': 'Wallonia (Belgium)', 'region_country': 'Belgium'}
# Country of ZW: Zimbabwe
# {'region_original': 'Zimbabwe', 'region_extended': 'Zimbabwe', 'region_country': 'Zimbabwe'}

# %%
with open(OUTPUT_FILE, "w", encoding="utf8") as fp:
    json.dump(flairs, fp, ensure_ascii=False, indent=4)

# %%
input_flairs = list()
with open(INPUT_FILE, "r") as fp:
    for line in fp:
        input_flairs.append(json.loads(line)["key"])
        
skipped_flairs = [flair for flair in input_flairs if flair not in flairs]
skipped_flairs += ["CRIM", "MORO"]

print(skipped_flairs)
# Out:
# ['ABKH', 'ANDO', 'AOST', 'ARUB', 'BERM', 'BKFG', 'CH-AI', 'CH-SO', 'CURA', 'DENK FORT', 'DOG', 'EART', 'ECUA', 'ES-RI', 'EURO', 'EURO STAR', 'FR-GUAD', 'FR-PACA FORT', 'FT', 'GAGA', 'KASH', 'KURD', 'MYAN', 'NAGO', 'NIST', 'OCCI', 'RROM', 'RUSS STAR', 'SAMI', 'SAUD', 'SI-050', 'SOMA', 'SRPS', 'SV', 'SZEK', 'UA-71', 'ULST', 'YEME', 'CRIM', 'MORO']

# %%
with open(RAW_FLAIR_FILE, "rb") as fp:
    raw_flairs = pickle.load(fp)

for key in skipped_flairs:
    print(key)
    counter = dict(sorted(raw_flairs[key].items(), key=lambda x: x[1], reverse=True))
    for flair_text, n in counter.items():
        print(f"\t({flair_text}: {n})")
# Out:
# ABKH
# 	(Half-Abkhazian half-Swede in Gotland: 35)
# 	(Half Abkhaz Half Crimean Tatar: 5)
# ANDO
# 	(🇸🇰🇨🇿: 15)
# 	(Bavarian European 🇪🇺: 1)
# 	(Catalan Republic: 1)
# AOST
# 	(RBiH: 2)
# 	(Socialist Utopia: 2)
# 	(Anarchist: 1)
# ARUB
# 	(East Frisia: 28)
# 	(Aruba: 12)
# 	(East Frisian: 8)
# 	(Само Слога Србина Спасава: 6)
# 	(Lithuania: 1)
# BERM
# 	(Lithium Anus -ia: 39)
# BKFG
# 	(Anarchist: 2)
# CH-AI
# 	(vcxz: 2)
# CH-SO
# 	(Irnbru for ever 🏴󠁧󠁢󠁳󠁣󠁴󠁿: 4)
# CURA
# 	(Silesia (CZ): 20)
# DENK FORT
# 	(Denmark: 2)
# DOG
# 	(He does it for free: 16)
# EART
# 	(Earth: 2280)
# 	(Republic of Türkiye: 114)
# 	(НАТОвской мордой: 89)
# 	(UA/US/EE/AT/FR/ES: 85)
# 	(Ceterum autem censeo Unionem Europaeam esse delendam: 67)
# 	(Life, Liberty and Property: 66)
# 	(Europe: 60)
# 	(Слава Україні: 59)
# 	(Slovenia, EU: 51)
# 	(Zealand: 41)
# 	(Republic of Turkiye: 41)
# 	(Geo-anthropoma: 37)
# 	(Citizen of the World: 35)
# 	(Baryonic Middle Finger: 34)
# 	(Autocracy with European characteristics: 31)
# 	(Somewhere in Asia: 24)
# 	(Dutchman living in Hong Kong: 23)
# 	(Bosnian Kingdom: 21)
# 	(Puck Futin: 20)
# 	(DNA% 57🏴󠁧󠁢󠁳󠁣󠁴󠁿19🇩🇪11🏴󠁧󠁢󠁥󠁮󠁧󠁿7🇳🇴6🇸🇮: 16)
# 	(Nefarious, Evil Globalist: 15)
# 	(Earth 🤷‍♂️: 14)
# 	(Costa Rica: 14)
# 	(I lost track where i'm from: 14)
# 	(Pro-Europe Anti-EU: 12)
# 	(🌎: 12)
# 	(Earth 🤍💙🤍: 12)
# 	(Texas: 9)
# 	(Dersim: 9)
# 	(55N: 8)
# 	(Debout! les damnés de la terre !: 8)
# 	(Ered Lithui: 8)
# 	(Descendant of an ancient civilization: 8)
# 	(Schleswig-Holstein (Germany): 7)
# 	(Reddit keeps silencing me: 7)
# 	(United States of America: 6)
# 	(Just a Thai passing by: 6)
# 	(Merry Christmas! c:: 6)
